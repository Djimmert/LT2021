# %%
from collections import defaultdict
import spacy
from spacy import displacy

nlp = spacy.load("en_core_web_sm")

duration_keywords = ['long', 'duration', 'minutes', 'time', 'length']
location_keywords = ['country', 'location', 'where']
time_keywords = ['century', 'year', 'centuries', 'when']
born_keywords

# %%
with open('../all_questions_sorted.txt', encoding='utf-8') as f:
    uncaught_questions = 0
    question_dict = defaultdict(lambda: 0)
    for line in f.readlines():
        
        # Parse the input
        parse = nlp(line)

        # Extract sentence structure
        lemmas = []
        pos = []
        dep = []
        for word in parse:
            lemmas.append(word.lemma_)
            pos.append(word.pos_)
            dep.append(word.dep_)

        sent = parse.text.replace("?", "")  # Strip question mark
        sent = sent.replace('"', "")  # Strip double apostrophe
        sent = sent.replace("'", "")  # Strip single apostrophe
        

        # Determine question type
        question_type = ""
        if 'pass' in dep:
            question_type = "passive"  # e.g. 'Which movies are directed by X?'
            break
        elif 'pobj' in dep:
            question_type = "XofY"  # e.g. 'Who is the director of X?'
        elif 'dobj' in dep:
            question_type = "verb_prop"  # e.g. 'Who directed X?'
        elif any(item in duration_keywords for item in sent.split(" ")):
            question_type = "duration"  # e.g. 'How long is X?'
        elif any(item in location_keywords for item in lemmas):
            # Falcon
            question_type = "location"
#             print(line)
        elif any(item in time_keywords for item in lemmas):
            # Falcon
            question_type = "time"
        elif parse[0].text == "What" or parse[0].text == "Which":
            if parse[1].pos_ == "NOUN":
                if "VERB" in pos:
                    question_type = "what_which_verb"
                    if "AUX" in pos and lemmas[pos.index("AUX")] == "be":
#                         print(line)
#                         print(parse[-4:-2].text.split())
                        pass
                    else:
#                         print(line)
                        pass
#                     print(lemmas[pos.index("AUX")])
#                     print(line)
#                     displacy.render(parse, jupyter=True, style="dep")
                else:
                    print(line)
                    print(parse[1:pos.index("AUX")].text.split(" "))
                    question_type = "what_which"
#                     displacy.render(parse, jupyter=True, style="dep")
            else:
                if 'about' in lemmas:
                    question_type = "about"
                else:
                    question_type = "what_is_Xs_Y"
        elif parse[0].text == "How":
            if parse[1].text == "tall":
                question_type = "tall"
                
            elif parse[1].text == "many":
                question_type = "count"
#                 print(line)
            else:
                question_type = "cost"
#                 print(line)
        else:
            uncaught_questions += 1
            newline = line.split(" ")
            question_type = " ".join(newline[0:2])
        question_dict[question_type] += 1
                
print(question_dict)
print(uncaught_questions)
# Out:
# What color is actor Michael Sheen's hair?
#
# ['color']
# What film genre is the Titanic?
#
# ['film', 'genre']
# What genre are the Harry Potter movies?
#
# ['genre']
# What genre is Argo?
#
# ['genre']
# What genre is Gravity part of?
#
# ['genre']
# What genre is Midsommar?
#
# ['genre']
# What genre is Schindler's List?
#
# ['genre']
# What genre is Skyfall?
#
# ['genre']
# What genre is Star Wars?
#
# ['genre']
# What genre is The Hangover?
#
# ['genre']
# What genre is the Netflix Death Note movie?
#
# ['genre']
# What genre(s) is the film Free Fire?
#
# ['genre(s)']
# What genres is The Hitman's Bodyguard?
#
# ['genres']
# What genres is the movie Grease?
#
# ['genres']
# What jewelry is Smeagol owner of?
#
# ['jewelry']
# What movie genre is "Persona"?
#
# ['movie', 'genre']
# What movie genre is The Impossible?
#
# ['movie', 'genre']
# What movie genre is the movie 'Pineapple express'?
#
# ['movie', 'genre']
# What species is Jean-Luc Picard?
#
# ['species']
# What sport is Space Jam about?
#
# ['sport']
# Which genre is Johnny English Strikes Again?
#
# ['genre']
# Which movie is the Disaster Artist about?
#
# ['movie']
# Which movies did Christopher Nolan direct?
#
# ['movies']
# Which movies did Christopher Nolan direct?
#
# ['movies']
# defaultdict(<function <lambda> at 0x7f89a7588a60>, {'XofY': 646, 'verb_prop': 188, 'By what': 1, 'For which': 1, 'location': 44, 'cost': 5, 'duration': 17, 'count': 17, 'time': 106, 'tall': 7, 'In what': 4, 'Is Brad': 1, 'Is Nicolas': 1, 'Is The': 1, 'Of which': 1, 'On what': 4, 'On which': 1, 'To what': 1, 'what_is_Xs_Y': 36, 'what_which_verb': 17, 'what_which': 24, 'about': 6, 'Who are': 2, 'Who directed': 1, 'Who is': 8, 'Why did': 1})
# 28
